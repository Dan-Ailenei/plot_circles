# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import animation
from time import sleep
import matplotlib.lines as mlines
# %matplotlib notebook

# %%
def map_val(x, input_start, input_end, output_start, output_end):
    return output_start + ((output_end - output_start) / (input_end - input_start)) * (x - input_start)

# %%
np.pi * np.power(2, 2)
# Out:
# 12.566370614359172

# %%
10 * 10
# Out:
# 100

# %%
DIM = 10
r = 2
circles = [
    plt.Circle((DIM/2, DIM/2), DIM /2),
    plt.Circle((7,7), 2, color='r'),
    plt.Circle((3,3), 2, color='r'),
    plt.Circle((3,7), 2, color='r'),
    plt.Circle((7,3), 2, color='r')
]


fig, ax = plt.subplots()
ax.set_xlim((0, DIM))
ax.set_ylim((0, DIM))
fig.gca().set_aspect('equal', adjustable='box')

for circle in circles:
    ax.add_artist(circle)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def point_on_circle(r, theta):
    return r * np.cos(theta), r * np.sin(theta)

# %%
DIM = 5
THETA_LENGHT = 2 * np.pi

def make_map(num_circles, fig, ax):
    r = DIM
    
    ratio = THETA_LENGHT / num_circles
    r_child = r / num_circles

    alfa = THETA_LENGHT / num_circles
    r_child = (r * np.sin(alfa/2)) / (1 + np.sin(alfa/2))
    r_imaginary_circle = r - r_child
    
    while r_imaginary_circle > 0:
        for i in range(num_circles):
            # draw circle
            theta = map_val(i, 0, num_circles, 0, THETA_LENGHT)
            ax.add_artist(plt.Circle(point_on_circle(r_imaginary_circle, theta), r_child, color='r'))
        sin_angle = r_child / (r_imaginary_circle- 2 * r_child)
        
        if sin_angle > 1:
            r_imaginary_circle -= 2 * r_child
            ax.add_artist(plt.Circle(point_on_circle(r_imaginary_circle, theta), r_child, color='r'))
            ax.add_artist(plt.Circle(point_on_circle(r_imaginary_circle, theta), r_child, color='r'))
            break
        elif sin_angle < -1:
            break
        
        ratio = 2 * np.arcsin(sin_angle)
        num_circles = int(THETA_LENGHT // ratio)
        r_imaginary_circle -= 2 * r_child

##        draw line
#         x1, y1 = point_on_circle(r, theta - ratio / 2)
#         x2, y2 = point_on_circle(r, theta - ratio / 2 + np.pi)
#         ax.add_line(mlines.Line2D([x1, x2], [y1, y2]))

# %%
def init():
    fig, ax = plt.subplots()
    ax.set_xlim((-DIM, DIM))
    ax.set_ylim((-DIM, DIM))
    fig.gca().set_aspect('equal', adjustable='box')

    r = DIM
    t = np.linspace(0, 2 * np.pi)

    x, y = point_on_circle(r, t)
    ax.plot(x, y)
    return fig, ax

# %%
fig, ax = init()
make_map(9, fig, ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.pi - np.arcsin(0.22766320995868958)
# Out:
# 2.9119154558409472

# %%
THETA_LENGHT
# Out:
# 6.283185307179586
